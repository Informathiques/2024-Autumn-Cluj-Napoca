# %% [markdown]
# <a href="https://colab.research.google.com/github/Informathiques/2024-Autumn-Cluj-Napoca/blob/main/Day2Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Initialisation

# %%
# @title
from google.colab import files
import pandas as pd

# %% [markdown]
# # Upload the data

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0cf990d0-14fd-4641-8491-ac9ac39cdca2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cf990d0-14fd-4641-8491-ac9ac39cdca2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load the JSON file into a pandas DataFrame
df = pd.read_json('student_data.json')

# Display the DataFrame
df.head()
# Out:
#   First Name Second Name  Height  Gender Date of Birth  \
# 0      Carla           P   166.0  Female    2008-04-19
# 1   Eléonore           M   162.0  Female    2007-10-21
# 2      Laura      Costea   168.0  Female    2007-06-24
# 3      Maria    Khirstan   163.0  Female    2005-10-16
# 4      Naila     Maelyne   165.0  Female    2009-07-19
#
#                         _id
# 0  671745a3cae9b67d0a5a6267
# 1  671745faa8077b1e0720a13e
# 2  6717464234938a7edcb19163
# 3  6717466e0220c3b94f8db15e
# 4  6717468015e202d37f659583

# %% [markdown]
# Bring your CSV data

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-44035103-176d-4c0a-af6e-87e6623333fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44035103-176d-4c0a-af6e-87e6623333fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Read the CSV into a DataFrame
df = pd.read_csv('student_data.csv')

# Display the data
df.head()
# Out:
#   First Name Second Name  Height  Gender Date of Birth  \
# 0      Carla           P   166.0  Female    2008-04-19
# 1   Eléonore           M   162.0  Female    2007-10-21
# 2      Laura      Costea   168.0  Female    2007-06-24
# 3      Maria    Khirstan   163.0  Female    2005-10-16
# 4      Naila     Maelyne   165.0  Female    2009-07-19
#
#                         _id
# 0  671745a3cae9b67d0a5a6267
# 1  671745faa8077b1e0720a13e
# 2  6717464234938a7edcb19163
# 3  6717466e0220c3b94f8db15e
# 4  6717468015e202d37f659583

# %%
import matplotlib.pyplot as plt

heights = df['Height']

plt.plot(heights)

plt.show()
