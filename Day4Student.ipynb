# %% [markdown]
# <a href="https://colab.research.google.com/github/Informathiques/2024-Autumn-Cluj-Napoca/blob/main/Day4Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Correlation

# %%
import requests
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Replace 'your_api_key' with your actual OpenWeatherMap API key
api_key = 'eaad329271adc36b53c4ec13b9070728'
city = 'Cluj-Napoca'  # You can change the city to any location
url = f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"

# Fetch weather data
response = requests.get(url)
weather_data = response.json()

# Extract temperature and humidity data for each time point
temperatures = []
humidities = []

for forecast in weather_data['list']:
    temperatures.append(forecast['main']['temp'])
    humidities.append(forecast['main']['humidity'])

# Convert lists to numpy arrays
temperatures = np.array(temperatures)
humidities = np.array(humidities)

# Calculate Pearson correlation
correlation, _ = pearsonr(temperatures, humidities)
print(f"Pearson correlation between temperature and humidity: {correlation}")

# Plot the correlation
plt.scatter(temperatures, humidities)
plt.title(f'Temperature vs. Humidity in {city}')
plt.xlabel('Temperature (°C)')
plt.ylabel('Humidity (%)')
plt.show()
# Out:
# Pearson correlation between temperature and humidity: -0.9855411949444741

# %%
weather_data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1729684800,
#    'main': {'temp': 15.71,
#     'feels_like': 14.59,
#     'temp_min': 15.71,
#     'temp_max': 16.96,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 974,
#     'humidity': 48,
#     'temp_kf': -1.25},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.69, 'deg': 17, 'gust': 1.68},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-10-23 12:00:00'},
#   {'dt': 1729695600,
#    'main': {'temp': 15.1,
#     'feels_like': 14,
#     'temp_min': 13.87,
#     'temp_max': 15.1,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 973,
#     'humidity': 51,
#     'temp_kf': 1.23},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
# ...
